# %%
# 1. Import packages
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers

# 2. Load & normalize data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 3. Form a dictionary of optimizers
optimizer_dict = {
    "adam": optimizers.Adam(learning_rate=0.001),
    "sgd": optimizers.SGD(learning_rate=0.01, momentum=0.9),
    "rmsprop": optimizers.RMSprop(learning_rate=0.001),
    "adagrad": optimizers.Adagrad(learning_rate=0.01),
    "adadelta": optimizers.Adadelta(learning_rate=1.0)
}

# 4. Function to build MLP model
def build_mlp():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# 5. Train & store results
results = {}
histories = {}

for opt_name, opt in optimizer_dict.items():
    print(f"\nTraining with optimizer: {opt_name}")
    model = build_mlp()
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    history = model.fit(
        x_train, y_train, 
        epochs=3, batch_size=128, 
        validation_split=0.1, verbose=1
    )
    
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
    results[opt_name] = {"accuracy": test_acc, "loss": test_loss}
    histories[opt_name] = history.history

# 6. Display final test results
print("\nFinal Test Results:")
for opt_name, res in results.items():
    print(f"{opt_name}: Accuracy = {res['accuracy']:.4f}, Loss = {res['loss']:.4f}")

# 7. Plot accuracy & loss for each optimizer
for opt_name, history in histories.items():
    plt.figure(figsize=(10, 4))
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Acc')
    plt.plot(history['val_accuracy'], label='Val Acc')
    plt.title(f"{opt_name.upper()} - Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title(f"{opt_name.upper()} - Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.tight_layout()
    plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
#
# Training with optimizer: adam
# c:\Users\aditk\miniconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9312 - loss: 0.2373 - val_accuracy: 0.9720 - val_loss: 0.0976
# Epoch 2/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9743 - loss: 0.0851 - val_accuracy: 0.9765 - val_loss: 0.0761
# Epoch 3/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9836 - loss: 0.0529 - val_accuracy: 0.9797 - val_loss: 0.0649
#
# Training with optimizer: sgd
# Epoch 1/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8733 - loss: 0.4623 - val_accuracy: 0.9398 - val_loss: 0.2074
# Epoch 2/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9417 - loss: 0.2035 - val_accuracy: 0.9627 - val_loss: 0.1395
# Epoch 3/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9568 - loss: 0.1495 - val_accuracy: 0.9685 - val_loss: 0.1183
#
# Training with optimizer: rmsprop
# Epoch 1/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9241 - loss: 0.2514 - val_accuracy: 0.9698 - val_loss: 0.1061
# Epoch 2/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9718 - loss: 0.0898 - val_accuracy: 0.9762 - val_loss: 0.0807
# Epoch 3/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9821 - loss: 0.0575 - val_accuracy: 0.9788 - val_loss: 0.0820
#
# Training with optimizer: adagrad
# Epoch 1/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8346 - loss: 0.6774 - val_accuracy: 0.9237 - val_loss: 0.2871
# Epoch 2/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9123 - loss: 0.3127 - val_accuracy: 0.9387 - val_loss: 0.2274
# Epoch 3/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9271 - loss: 0.2593 - val_accuracy: 0.9433 - val_loss: 0.2014
#
# Training with optimizer: adadelta
# Epoch 1/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9166 - loss: 0.2781 - val_accuracy: 0.9672 - val_loss: 0.1098
# Epoch 2/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9690 - loss: 0.1021 - val_accuracy: 0.9730 - val_loss: 0.0895
# Epoch 3/3
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9801 - loss: 0.0651 - val_accuracy: 0.9793 - val_loss: 0.0727
#
# Final Test Results:
# adam: Accuracy = 0.9789, Loss = 0.0711
# sgd: Accuracy = 0.9620, Loss = 0.1291
# rmsprop: Accuracy = 0.9765, Loss = 0.0848
# adagrad: Accuracy = 0.9332, Loss = 0.2341
# adadelta: Accuracy = 0.9759, Loss = 0.0732
